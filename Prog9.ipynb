# %%
import numpy as np
a=np.array(['madhu','sai','payal','ashwini','rahul'])
print(c.dtype)
# Out:
# <U7

# %%
import numpy as np
a= np.array([[1,2,3],[4,5,6]])
b= a.reshape(-1)
print(a)
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3 4 5 6]

# %%
import numpy as np
a= np.array([[1,2,3],[4,5,6]])
b= a.reshape(-2)
print(a)
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [1 2 3 4 5 6]

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
c=np.concatenate((a,b))
print(a)
print(b)
print(c)
# Out:
# [1 2 3]
# [4 5 6]
# [1 2 3 4 5 6]

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
c=np.stack((a,b),axis=0)
print(a)
print(b)
print(c)
# Out:
# [1 2 3]
# [4 5 6]
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
c=np.stack((a,b),axis=1)
print(a)
print(b)
print(c)
# Out:
# [1 2 3]
# [4 5 6]
# [[1 4]
#  [2 5]
#  [3 6]]

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
c=np.vstack((a,b))
print(a)
print(b)
print(c)
# Out:
# [1 2 3]
# [4 5 6]
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
a=np.array([1,2,3])
b=np.array([4,5,6])
c=np.dstack((a,b))
print(a)
print(b)
print(c)
# Out:
# [1 2 3]
# [4 5 6]
# [[[1 4]
#   [2 5]
#   [3 6]]]

# %% [markdown]
# #Splitting a given array

# %%
import numpy as np
a=np.array([1,2,3,4,5,6])
b=np.array_split(a,3)
print(b)
# Out:
# [array([1, 2]), array([3, 4]), array([5, 6])]

# %%
import numpy as np
a=np.array([1,2,3,4,5,6])
b=np.array_split(a,4)
print(b)
# Out:
# [array([1, 2]), array([3, 4]), array([5]), array([6])]

# %%
import numpy as np
a=np.array([414,42,45,44])
b=a[[True,True,True,False]]
print(b)
# Out:
# [414  42  45]

# %%
import numpy as np
a=np.array([414,42,45,44])
filter_a=a>42
b=a[filter_a]
print(filter_a)
print(b)
# Out:
# [ True False  True  True]
# [414  45  44]

# %%
import matplotlib
print( matplotlib.__version__)
# Out:
# 3.2.2

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([0,6])
y=np.array([0,6])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([1,3])
y=np.array([8,10])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,2])
ypoints = np.array([0,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,2])
ypoints = np.array([0,10])

plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8])
ypoints = np.array([3,6,1,10])

plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,2,24,55,8])

plt.plot(xpoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,33.1,2,24,54,22])

plt.plot(xpoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([1,2,6,8])
y=np.array([3,8,1,10])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,33.1,2,24,54,22])

plt.plot(xpoints,marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,2,24,55,8])

plt.plot(xpoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,2,24,55,8])

plt.plot(xpoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,33.1,2,24,54,22])

plt.plot(xpoints,marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,33.1,2,24,54,22])

plt.plot(xpoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,2,24,55,8])

plt.plot(xpoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,33.1,2,24,54,22])

plt.plot(xpoints, 'o--r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,2,6,8,33,22,33.1,2,24,54,22])

plt.plot(xpoints, 'o-.r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([1,2,6,8,33,22,33,1,2,22,54,22])
plt.plot(x,'o-.r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([0,1,2,3])
y=np.array([3,5,2,10])
plt.subplot(1,2,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([13,23,32,40])
plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x =np.array([0,1,2,3])
y =np.array([3,5,2,10])
plt.subplot(2,2,1)
plt.plot(x,y)


x =np.array([0,1,2,3])
y =np.array([13,25,32,40])
plt.subplot(2,2,2)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x =np.array([0,1,2,3])
y =np.array([3,5,2,10])
plt.subplot(1,2,1)
plt.plot(x,y)


x =np.array([0,1,2,3])
y =np.array([13,25,32,40])
plt.subplot(2,2,2)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x =np.array([0,1,2,3])
y =np.array([3,5,2,10])
plt.subplot(1,2,2)
plt.plot(x,y)


x =np.array([0,1,2,3])
y =np.array([13,25,32,40])
plt.subplot(1,2,1)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,5,2,10])
plt.subplot(2,3,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([13,25,32,40])
plt.subplot(2,3,2)
plt.plot(x,y)

x=np.array([2,13,2,13])
y=np.array([13,5,32,40])
plt.subplot(2,3,3)
plt.plot(x,y)

x=np.array([10,11,12,13])
y=np.array([3,5,32,20])
plt.subplot(2,3,4)
plt.plot(x,y)

x=np.array([12,13,2,113])
y=np.array([13,15,132,40])
plt.subplot(2,3,5)
plt.plot(x,y)

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x =np.array([0,1,2,3])
y =np.array([3,5,2,10])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title('SALES')


x =np.array([0,1,2,3])
y =np.array([13,25,32,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title('INCOME')

plt.suptitle("workshop of Acharya College")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x =np.array([0,1,2,3])
y =np.array([13,25,32,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title('INCOME')

plt.suptitle("workshop of Acharya College")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x =np.array([0,1,2,3])
y =np.array([3,5,2,10])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title('SALES')

plt.suptitle("workshop of Acharya College")
plt.show()
